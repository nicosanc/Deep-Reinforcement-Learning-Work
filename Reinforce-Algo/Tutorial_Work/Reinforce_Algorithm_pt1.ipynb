# %%
from torch.distributions import Categorical
import gym
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim

gamma = 0.99

# %%
class Pi(nn.Module):
  def __init__(self, in_dim, out_dim) -> None:
    super(Pi, self).__init__()
    layers = [
        nn.Linear(in_dim, 64),
        nn.ReLU(),
        nn.Linear(64, out_dim)
    ]
    # Sequential has to take in the individual elements
    # of the list as params, not just the list itself
    self.model = nn.Sequential(*layers)
    self.onpolicy_reset()
    self.train()

  def forward(self, x):
    return self.model(x)

  def onpolicy_reset(self):
    self.log_probs = []
    self.rewards = []

  def act(self, state):
    x = torch.from_numpy(state.astype(np.float32))
    pdparam = self.forward(x)
    pd = Categorical(logits=pdparam)
    action = pd.sample()
    log_prob = pd.log_prob(action)
    self.log_probs.append(log_prob)
    return action.item()

def train(pi, optimizer):
  T = len(pi.rewards) # The max timestep for the given episode
  returns = np.empty(T, dtype=np.float32) # The array of returns
  future_return = 0.0
  # iterate from the end to the beginning to collect returns for the
  # trajectory -> done from the end to be able to use future returns
  # to calculate return from early episodes
  for t in reversed(range(T)):
    future_return = pi.rewards[t] + gamma * future_return
    returns[t] = future_return
  returns = torch.tensor(returns)
  log_probs = torch.stack(pi.log_probs)
  loss = - log_probs * returns
  loss = torch.sum(loss)
  optimizer.zero_grad()
  loss.backward()
  optimizer.step()
  return loss

def main():
  env = gym.make("CartPole-v0")
  in_dim = env.observation_space.shape[0]
  out_dim = env.action_space.n
  pi = Pi(in_dim, out_dim)
  optimizer = optim.Adam(pi.parameters(), lr =0.01)
  for episode in range(300):
    state = env.reset()
    for t in range(200):
      action = pi.act(state)
      state, reward, done, _ = env.step(action)
      pi.rewards.append(reward)
      env.render()
      if done:
        break
    loss = train(pi, optimizer)
    total_reward = sum(pi.rewards)
    solved = total_reward > 195.0
    pi.onpolicy_reset()
    print(f"Episode {episode}, loss: {loss}, total_reward: {total_reward}, solved: {solved}")

if __name__ == "__main__":
  main()
# Out:
# /usr/local/lib/python3.10/dist-packages/gym/core.py:49: DeprecationWarning: WARN: You are calling render method, but you didn't specified the argument render_mode at environment initialization. To maintain backward compatibility, the environment will render in human mode.
# If you want to render in human mode, initialize the environment in this way: gym.make('EnvName', render_mode='human') and don't call the render method.
# See here for more information: https://www.gymlibrary.ml/content/api/
#   deprecation(
# Episode 0, loss: 375.53045654296875, total_reward: 34.0, solved: False
# Episode 1, loss: 1029.369140625, total_reward: 60.0, solved: False
# Episode 2, loss: 50.84876251220703, total_reward: 11.0, solved: False
# Episode 3, loss: 237.23043823242188, total_reward: 27.0, solved: False
# Episode 4, loss: 185.2281494140625, total_reward: 23.0, solved: False
# Episode 5, loss: 595.0177001953125, total_reward: 45.0, solved: False
# Episode 6, loss: 85.96440887451172, total_reward: 15.0, solved: False
# Episode 7, loss: 72.83362579345703, total_reward: 14.0, solved: False
# Episode 8, loss: 531.07568359375, total_reward: 43.0, solved: False
# Episode 9, loss: 333.6488342285156, total_reward: 33.0, solved: False
# Episode 10, loss: 3038.112060546875, total_reward: 114.0, solved: False
# Episode 11, loss: 105.67044830322266, total_reward: 18.0, solved: False
# Episode 12, loss: 136.82830810546875, total_reward: 18.0, solved: False
# Episode 13, loss: 141.8507843017578, total_reward: 21.0, solved: False
# Episode 14, loss: 191.17494201660156, total_reward: 25.0, solved: False
# Episode 15, loss: 217.5901336669922, total_reward: 27.0, solved: False
# Episode 16, loss: 78.02466583251953, total_reward: 15.0, solved: False
# Episode 17, loss: 429.39019775390625, total_reward: 37.0, solved: False
# Episode 18, loss: 1276.10595703125, total_reward: 69.0, solved: False
# Episode 19, loss: 1855.547607421875, total_reward: 86.0, solved: False
# Episode 20, loss: 220.0941162109375, total_reward: 27.0, solved: False
# Episode 21, loss: 258.8619384765625, total_reward: 28.0, solved: False
# Episode 22, loss: 2056.5654296875, total_reward: 93.0, solved: False
# Episode 23, loss: 165.63232421875, total_reward: 23.0, solved: False
# Episode 24, loss: 370.4291687011719, total_reward: 35.0, solved: False
# Episode 25, loss: 265.1715087890625, total_reward: 30.0, solved: False
# Episode 26, loss: 1376.0577392578125, total_reward: 70.0, solved: False
# Episode 27, loss: 855.0791015625, total_reward: 57.0, solved: False
# Episode 28, loss: 215.21156311035156, total_reward: 27.0, solved: False
# Episode 29, loss: 651.167236328125, total_reward: 48.0, solved: False
# Episode 30, loss: 2948.3935546875, total_reward: 115.0, solved: False
# Episode 31, loss: 500.0879821777344, total_reward: 41.0, solved: False
# Episode 32, loss: 7117.78662109375, total_reward: 200.0, solved: True
# Episode 33, loss: 147.5518035888672, total_reward: 21.0, solved: False
# Episode 34, loss: 207.8427276611328, total_reward: 25.0, solved: False
# Episode 35, loss: 3152.708740234375, total_reward: 122.0, solved: False
# Episode 36, loss: 1447.4105224609375, total_reward: 79.0, solved: False
# Episode 37, loss: 206.8484649658203, total_reward: 24.0, solved: False
# Episode 38, loss: 1227.5262451171875, total_reward: 70.0, solved: False
# Episode 39, loss: 2030.809326171875, total_reward: 94.0, solved: False
# Episode 40, loss: 6786.630859375, total_reward: 200.0, solved: True
# Episode 41, loss: 1814.8070068359375, total_reward: 85.0, solved: False
# Episode 42, loss: 115.5599136352539, total_reward: 18.0, solved: False
# Episode 43, loss: 3400.10205078125, total_reward: 128.0, solved: False
# Episode 44, loss: 1292.990234375, total_reward: 74.0, solved: False
# Episode 45, loss: 4553.693359375, total_reward: 154.0, solved: False
# Episode 46, loss: 1818.020751953125, total_reward: 87.0, solved: False
# Episode 47, loss: 1635.063720703125, total_reward: 82.0, solved: False
# Episode 48, loss: 2425.4755859375, total_reward: 107.0, solved: False
# Episode 49, loss: 1918.9700927734375, total_reward: 90.0, solved: False
# Episode 50, loss: 197.15594482421875, total_reward: 26.0, solved: False
# Episode 51, loss: 6976.92919921875, total_reward: 200.0, solved: True
# Episode 52, loss: 3317.909423828125, total_reward: 129.0, solved: False
# Episode 53, loss: 1724.047119140625, total_reward: 83.0, solved: False
# Episode 54, loss: 3979.73974609375, total_reward: 147.0, solved: False
# Episode 55, loss: 1820.34619140625, total_reward: 90.0, solved: False
# Episode 56, loss: 2184.813232421875, total_reward: 98.0, solved: False
# Episode 57, loss: 2291.06396484375, total_reward: 101.0, solved: False
# Episode 58, loss: 6646.921875, total_reward: 200.0, solved: True
# Episode 59, loss: 700.8276977539062, total_reward: 53.0, solved: False
# Episode 60, loss: 1497.3553466796875, total_reward: 79.0, solved: False
# Episode 61, loss: 457.8436584472656, total_reward: 40.0, solved: False
# Episode 62, loss: 6593.74267578125, total_reward: 200.0, solved: True
# Episode 63, loss: 1111.019775390625, total_reward: 67.0, solved: False
# Episode 64, loss: 6744.66943359375, total_reward: 200.0, solved: True
# Episode 65, loss: 6855.62060546875, total_reward: 200.0, solved: True
# Episode 66, loss: 1996.029296875, total_reward: 92.0, solved: False
# Episode 67, loss: 1728.565673828125, total_reward: 87.0, solved: False
# Episode 68, loss: 3413.203857421875, total_reward: 131.0, solved: False
# Episode 69, loss: 6712.279296875, total_reward: 200.0, solved: True
# Episode 70, loss: 6610.1298828125, total_reward: 200.0, solved: True
# Episode 71, loss: 4643.13671875, total_reward: 157.0, solved: False
# Episode 72, loss: 6877.35888671875, total_reward: 200.0, solved: True
# Episode 73, loss: 3892.807373046875, total_reward: 146.0, solved: False
# Episode 74, loss: 3253.57275390625, total_reward: 126.0, solved: False
# Episode 75, loss: 2835.83837890625, total_reward: 119.0, solved: False
# Episode 76, loss: 6753.0205078125, total_reward: 200.0, solved: True
# Episode 77, loss: 1358.299072265625, total_reward: 75.0, solved: False
# Episode 78, loss: 6615.77880859375, total_reward: 200.0, solved: True
# Episode 79, loss: 268.4905090332031, total_reward: 27.0, solved: False
# Episode 80, loss: 6163.92626953125, total_reward: 200.0, solved: True
# Episode 81, loss: 6853.44384765625, total_reward: 200.0, solved: True
# Episode 82, loss: 6294.89404296875, total_reward: 200.0, solved: True
# Episode 83, loss: 6357.61083984375, total_reward: 200.0, solved: True
# Episode 84, loss: 1695.20751953125, total_reward: 83.0, solved: False
# Episode 85, loss: 6935.251953125, total_reward: 200.0, solved: True
# Episode 86, loss: 6396.54052734375, total_reward: 200.0, solved: True
# Episode 87, loss: 6256.5234375, total_reward: 200.0, solved: True
# Episode 88, loss: 6251.93896484375, total_reward: 200.0, solved: True
# Episode 89, loss: 6448.27490234375, total_reward: 200.0, solved: True
# Episode 90, loss: 6349.3076171875, total_reward: 200.0, solved: True
# Episode 91, loss: 6394.3232421875, total_reward: 200.0, solved: True
# Episode 92, loss: 6176.99267578125, total_reward: 200.0, solved: True
# Episode 93, loss: 6483.646484375, total_reward: 200.0, solved: True
# Episode 94, loss: 6529.72509765625, total_reward: 200.0, solved: True
# Episode 95, loss: 6326.5634765625, total_reward: 200.0, solved: True
# Episode 96, loss: 6282.92529296875, total_reward: 200.0, solved: True
# Episode 97, loss: 6199.4716796875, total_reward: 200.0, solved: True
# Episode 98, loss: 6512.17529296875, total_reward: 200.0, solved: True
# Episode 99, loss: 6289.181640625, total_reward: 200.0, solved: True
# Episode 100, loss: 6416.13330078125, total_reward: 200.0, solved: True
# Episode 101, loss: 7098.9951171875, total_reward: 200.0, solved: True
# Episode 102, loss: 6182.4384765625, total_reward: 200.0, solved: True
# Episode 103, loss: 5960.75, total_reward: 200.0, solved: True
# Episode 104, loss: 6291.275390625, total_reward: 200.0, solved: True
# Episode 105, loss: 6499.75830078125, total_reward: 200.0, solved: True
# Episode 106, loss: 6549.1279296875, total_reward: 200.0, solved: True
# Episode 107, loss: 6132.4970703125, total_reward: 200.0, solved: True
# Episode 108, loss: 5981.23193359375, total_reward: 200.0, solved: True
# Episode 109, loss: 6407.7822265625, total_reward: 200.0, solved: True
# Episode 110, loss: 6145.71142578125, total_reward: 200.0, solved: True
# Episode 111, loss: 6232.4248046875, total_reward: 200.0, solved: True
# Episode 112, loss: 6303.5732421875, total_reward: 200.0, solved: True
# Episode 113, loss: 6178.23095703125, total_reward: 200.0, solved: True
# Episode 114, loss: 6386.98486328125, total_reward: 200.0, solved: True
# Episode 115, loss: 6414.78076171875, total_reward: 200.0, solved: True
# Episode 116, loss: 6298.01123046875, total_reward: 200.0, solved: True
# Episode 117, loss: 5746.9189453125, total_reward: 200.0, solved: True
# Episode 118, loss: 6679.54345703125, total_reward: 200.0, solved: True
# Episode 119, loss: 6044.689453125, total_reward: 200.0, solved: True
# Episode 120, loss: 6117.4345703125, total_reward: 200.0, solved: True
# Episode 121, loss: 6225.27099609375, total_reward: 200.0, solved: True
# Episode 122, loss: 6465.0302734375, total_reward: 200.0, solved: True
# Episode 123, loss: 6261.041015625, total_reward: 200.0, solved: True
# Episode 124, loss: 6206.2607421875, total_reward: 200.0, solved: True
# Episode 125, loss: 6327.3369140625, total_reward: 200.0, solved: True
# Episode 126, loss: 6342.4482421875, total_reward: 200.0, solved: True
# Episode 127, loss: 6221.23388671875, total_reward: 200.0, solved: True
# Episode 128, loss: 5927.189453125, total_reward: 200.0, solved: True
# Episode 129, loss: 3488.397216796875, total_reward: 137.0, solved: False
# Episode 130, loss: 5976.21875, total_reward: 200.0, solved: True
# Episode 131, loss: 6231.40380859375, total_reward: 200.0, solved: True
# Episode 132, loss: 6048.4921875, total_reward: 200.0, solved: True
# Episode 133, loss: 6073.37548828125, total_reward: 200.0, solved: True
# Episode 134, loss: 5790.75341796875, total_reward: 200.0, solved: True
# Episode 135, loss: 5996.37255859375, total_reward: 200.0, solved: True
# Episode 136, loss: 6203.5546875, total_reward: 200.0, solved: True
# Episode 137, loss: 5868.3447265625, total_reward: 200.0, solved: True
# Episode 138, loss: 5692.939453125, total_reward: 200.0, solved: True
# Episode 139, loss: 6000.333984375, total_reward: 200.0, solved: True
# Episode 140, loss: 6001.6533203125, total_reward: 200.0, solved: True
# Episode 141, loss: 5694.7275390625, total_reward: 200.0, solved: True
# Episode 142, loss: 5873.3671875, total_reward: 200.0, solved: True
# Episode 143, loss: 5030.1474609375, total_reward: 200.0, solved: True
# Episode 144, loss: 5702.6962890625, total_reward: 200.0, solved: True
# Episode 145, loss: 5727.373046875, total_reward: 200.0, solved: True
# Episode 146, loss: 5356.18359375, total_reward: 200.0, solved: True
# Episode 147, loss: 2538.9833984375, total_reward: 124.0, solved: False
# Episode 148, loss: 5723.73828125, total_reward: 200.0, solved: True
# Episode 149, loss: 5512.689453125, total_reward: 200.0, solved: True
# Episode 150, loss: 5405.92626953125, total_reward: 188.0, solved: False
# Episode 151, loss: 2880.0029296875, total_reward: 124.0, solved: False
# Episode 152, loss: 5695.26416015625, total_reward: 193.0, solved: False
# Episode 153, loss: 1674.899658203125, total_reward: 96.0, solved: False
# Episode 154, loss: 3981.3251953125, total_reward: 158.0, solved: False
# Episode 155, loss: 3459.271728515625, total_reward: 147.0, solved: False
# Episode 156, loss: 5335.552734375, total_reward: 181.0, solved: False
# Episode 157, loss: 3552.322998046875, total_reward: 142.0, solved: False
# Episode 158, loss: 4150.04931640625, total_reward: 165.0, solved: False
# Episode 159, loss: 5094.1357421875, total_reward: 187.0, solved: False
# Episode 160, loss: 4624.9697265625, total_reward: 170.0, solved: False
# Episode 161, loss: 5753.0625, total_reward: 200.0, solved: True
# Episode 162, loss: 5738.2509765625, total_reward: 200.0, solved: True
# Episode 163, loss: 5514.630859375, total_reward: 200.0, solved: True
# Episode 164, loss: 1695.5694580078125, total_reward: 95.0, solved: False
# Episode 165, loss: 5105.8525390625, total_reward: 193.0, solved: False
# Episode 166, loss: 5961.40625, total_reward: 200.0, solved: True
# Episode 167, loss: 5779.18798828125, total_reward: 200.0, solved: True
# Episode 168, loss: 5823.419921875, total_reward: 200.0, solved: True
# Episode 169, loss: 6295.44775390625, total_reward: 200.0, solved: True
# Episode 170, loss: 4949.93115234375, total_reward: 177.0, solved: False
# Episode 171, loss: 5083.953125, total_reward: 200.0, solved: True
# Episode 172, loss: 5694.2666015625, total_reward: 200.0, solved: True
# Episode 173, loss: 3037.667724609375, total_reward: 134.0, solved: False
# Episode 174, loss: 5224.98974609375, total_reward: 182.0, solved: False
# Episode 175, loss: 3857.088134765625, total_reward: 151.0, solved: False
# Episode 176, loss: 3167.341796875, total_reward: 139.0, solved: False
# Episode 177, loss: 3044.640625, total_reward: 141.0, solved: False
# Episode 178, loss: 2630.64794921875, total_reward: 124.0, solved: False
# Episode 179, loss: 3306.769775390625, total_reward: 141.0, solved: False
# Episode 180, loss: 3778.11572265625, total_reward: 152.0, solved: False
# Episode 181, loss: 3971.239501953125, total_reward: 168.0, solved: False
# Episode 182, loss: 3629.5166015625, total_reward: 145.0, solved: False
# Episode 183, loss: 4246.06787109375, total_reward: 161.0, solved: False
# Episode 184, loss: 3311.153076171875, total_reward: 145.0, solved: False
# Episode 185, loss: 3703.875732421875, total_reward: 150.0, solved: False
# Episode 186, loss: 2783.943603515625, total_reward: 126.0, solved: False
# Episode 187, loss: 274.088134765625, total_reward: 36.0, solved: False
# Episode 188, loss: 4155.8212890625, total_reward: 162.0, solved: False
# Episode 189, loss: 5288.21533203125, total_reward: 187.0, solved: False
# Episode 190, loss: 6075.4013671875, total_reward: 199.0, solved: True
# Episode 191, loss: 5329.7861328125, total_reward: 191.0, solved: False
# Episode 192, loss: 5779.1767578125, total_reward: 200.0, solved: True
# Episode 193, loss: 5790.65869140625, total_reward: 200.0, solved: True
# Episode 194, loss: 5804.8642578125, total_reward: 200.0, solved: True
# Episode 195, loss: 6072.53173828125, total_reward: 200.0, solved: True
# Episode 196, loss: 5813.51953125, total_reward: 200.0, solved: True
# Episode 197, loss: 5574.69775390625, total_reward: 200.0, solved: True
# Episode 198, loss: 5496.8447265625, total_reward: 200.0, solved: True
# Episode 199, loss: 5163.72119140625, total_reward: 187.0, solved: False
# Episode 200, loss: 6004.5087890625, total_reward: 200.0, solved: True
# Episode 201, loss: 5754.2080078125, total_reward: 200.0, solved: True
# Episode 202, loss: 6257.9462890625, total_reward: 200.0, solved: True
# Episode 203, loss: 5678.4736328125, total_reward: 200.0, solved: True
# Episode 204, loss: 5837.17822265625, total_reward: 200.0, solved: True
# Episode 205, loss: 5544.71533203125, total_reward: 200.0, solved: True
# Episode 206, loss: 5674.69970703125, total_reward: 200.0, solved: True
# Episode 207, loss: 5756.8134765625, total_reward: 200.0, solved: True
# Episode 208, loss: 5644.75537109375, total_reward: 200.0, solved: True
# Episode 209, loss: 6582.25732421875, total_reward: 200.0, solved: True
# Episode 210, loss: 5612.4306640625, total_reward: 200.0, solved: True
# Episode 211, loss: 5827.4404296875, total_reward: 200.0, solved: True
# Episode 212, loss: 5530.19482421875, total_reward: 200.0, solved: True
# Episode 213, loss: 5415.431640625, total_reward: 200.0, solved: True
# Episode 214, loss: 5036.88330078125, total_reward: 200.0, solved: True
# Episode 215, loss: 5769.4072265625, total_reward: 200.0, solved: True
# Episode 216, loss: 5560.68359375, total_reward: 200.0, solved: True
# Episode 217, loss: 5627.08251953125, total_reward: 200.0, solved: True
# Episode 218, loss: 5070.4599609375, total_reward: 200.0, solved: True
# Episode 219, loss: 5744.935546875, total_reward: 200.0, solved: True
# Episode 220, loss: 5793.3271484375, total_reward: 200.0, solved: True
# Episode 221, loss: 5258.55517578125, total_reward: 200.0, solved: True
# Episode 222, loss: 6264.435546875, total_reward: 200.0, solved: True
# Episode 223, loss: 5061.236328125, total_reward: 200.0, solved: True
# Episode 224, loss: 5294.34423828125, total_reward: 200.0, solved: True
# Episode 225, loss: 5063.849609375, total_reward: 200.0, solved: True
# Episode 226, loss: 4726.265625, total_reward: 183.0, solved: False
# Episode 227, loss: 5432.1552734375, total_reward: 200.0, solved: True
# Episode 228, loss: 5367.6728515625, total_reward: 200.0, solved: True
# Episode 229, loss: 5305.56201171875, total_reward: 200.0, solved: True
# Episode 230, loss: 4687.47900390625, total_reward: 200.0, solved: True
# Episode 231, loss: 4895.669921875, total_reward: 200.0, solved: True
# Episode 232, loss: 4670.14404296875, total_reward: 200.0, solved: True
# Episode 233, loss: 5529.79638671875, total_reward: 200.0, solved: True
# Episode 234, loss: 4757.83740234375, total_reward: 200.0, solved: True
# Episode 235, loss: 5009.7705078125, total_reward: 200.0, solved: True
# Episode 236, loss: 5312.556640625, total_reward: 200.0, solved: True
# Episode 237, loss: 5031.8671875, total_reward: 193.0, solved: False
# Episode 238, loss: 4417.64111328125, total_reward: 200.0, solved: True
# Episode 239, loss: 5248.77587890625, total_reward: 200.0, solved: True
# Episode 240, loss: 4979.296875, total_reward: 200.0, solved: True
# Episode 241, loss: 4290.95849609375, total_reward: 200.0, solved: True
# Episode 242, loss: 5161.44384765625, total_reward: 200.0, solved: True
# Episode 243, loss: 5039.1533203125, total_reward: 200.0, solved: True
# Episode 244, loss: 4579.4208984375, total_reward: 200.0, solved: True
# Episode 245, loss: 4482.537109375, total_reward: 200.0, solved: True
# Episode 246, loss: 5074.12646484375, total_reward: 200.0, solved: True
# Episode 247, loss: 2697.328125, total_reward: 132.0, solved: False
# Episode 248, loss: 2855.303466796875, total_reward: 147.0, solved: False
# Episode 249, loss: 4725.90869140625, total_reward: 200.0, solved: True
# Episode 250, loss: 3434.646484375, total_reward: 159.0, solved: False
# Episode 251, loss: 3630.4228515625, total_reward: 159.0, solved: False
# Episode 252, loss: 4639.6171875, total_reward: 200.0, solved: True
# Episode 253, loss: 4808.072265625, total_reward: 200.0, solved: True
# Episode 254, loss: 1431.0079345703125, total_reward: 87.0, solved: False
# Episode 255, loss: 2955.0205078125, total_reward: 144.0, solved: False
# Episode 256, loss: 3564.55517578125, total_reward: 169.0, solved: False
# Episode 257, loss: 1168.9134521484375, total_reward: 85.0, solved: False
# Episode 258, loss: 5320.50634765625, total_reward: 200.0, solved: True
# Episode 259, loss: 1648.92041015625, total_reward: 97.0, solved: False
# Episode 260, loss: 5473.35205078125, total_reward: 200.0, solved: True
# Episode 261, loss: 2044.2403564453125, total_reward: 109.0, solved: False
# Episode 262, loss: 1256.590087890625, total_reward: 85.0, solved: False
# Episode 263, loss: 4742.9609375, total_reward: 200.0, solved: True
# Episode 264, loss: 3833.658203125, total_reward: 170.0, solved: False
# Episode 265, loss: 5413.24853515625, total_reward: 200.0, solved: True
# Episode 266, loss: 1213.15869140625, total_reward: 82.0, solved: False
# Episode 267, loss: 1902.021728515625, total_reward: 104.0, solved: False
# Episode 268, loss: 5355.8369140625, total_reward: 200.0, solved: True
# Episode 269, loss: 5254.25244140625, total_reward: 200.0, solved: True
# Episode 270, loss: 1569.910888671875, total_reward: 90.0, solved: False
# Episode 271, loss: 5439.05908203125, total_reward: 200.0, solved: True
# Episode 272, loss: 5007.94970703125, total_reward: 200.0, solved: True
# Episode 273, loss: 5101.0029296875, total_reward: 200.0, solved: True
# Episode 274, loss: 5561.36865234375, total_reward: 200.0, solved: True
# Episode 275, loss: 5465.931640625, total_reward: 200.0, solved: True
# Episode 276, loss: 1571.1368408203125, total_reward: 94.0, solved: False
# Episode 277, loss: 5314.5234375, total_reward: 200.0, solved: True
# Episode 278, loss: 5547.30419921875, total_reward: 200.0, solved: True
# Episode 279, loss: 5526.4990234375, total_reward: 200.0, solved: True
# Episode 280, loss: 5400.73291015625, total_reward: 200.0, solved: True
# Episode 281, loss: 5464.8896484375, total_reward: 200.0, solved: True
# Episode 282, loss: 5066.36962890625, total_reward: 200.0, solved: True
# Episode 283, loss: 5556.5537109375, total_reward: 200.0, solved: True
# Episode 284, loss: 5786.94189453125, total_reward: 200.0, solved: True
# Episode 285, loss: 5483.86669921875, total_reward: 200.0, solved: True
# Episode 286, loss: 5035.11083984375, total_reward: 200.0, solved: True
# Episode 287, loss: 4625.7880859375, total_reward: 182.0, solved: False
# Episode 288, loss: 4876.40283203125, total_reward: 200.0, solved: True
# Episode 289, loss: 5318.634765625, total_reward: 200.0, solved: True
# Episode 290, loss: 5185.76123046875, total_reward: 197.0, solved: True
# Episode 291, loss: 4733.3388671875, total_reward: 186.0, solved: False
# Episode 292, loss: 4681.2822265625, total_reward: 200.0, solved: True
# Episode 293, loss: 4994.7646484375, total_reward: 200.0, solved: True
# Episode 294, loss: 5245.1357421875, total_reward: 200.0, solved: True
# Episode 295, loss: 5862.888671875, total_reward: 200.0, solved: True
# Episode 296, loss: 5423.64501953125, total_reward: 200.0, solved: True
# Episode 297, loss: 5392.46630859375, total_reward: 200.0, solved: True
# Episode 298, loss: 5110.37890625, total_reward: 200.0, solved: True
# Episode 299, loss: 5484.77001953125, total_reward: 200.0, solved: True
